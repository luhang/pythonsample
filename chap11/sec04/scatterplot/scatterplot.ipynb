# %%
# 「清涼飲料水売上.txt」をデータフレームに読み込んで出力

import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# CSVファイルの読み込み
df = pd.read_csv('清涼飲料水売上.csv', encoding='cp932')

plt.plot(df['最高気温'],       # x軸は気温
         df['清涼飲料売上数'], # y軸は売上数 
         'o'                 # ドットをプロット
        )
plt.xlabel('temperatur')     # x軸ラベル
plt.ylabel('sales')          # y軸ラベル
# Out:
# Text(0, 0.5, 'sales')
